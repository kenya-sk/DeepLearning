# %% [markdown]
# # ニューラルネットワークの学習におけるテクニック

# %%
# %matplotlib inline
import sys, os
sys.path.append("../deep-learning-from-scratch/")
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet

# %% [markdown]
# # パラメータの更新

# %% [markdown]
# # SGD(stochastic gradient descent)

# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %% [markdown]
# # Momentum

# %%
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)
                
        for ley in params.keys():
            self.v[key] = self.momentum * self.v[key] - self.lr * grads[key]
            params[key] += self.v[key]

# %% [markdown]
# # AdaGrad(Adaptive Gradient)

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, var in params.items():
                self.h[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + np.e**(-7))

# %% [markdown]
# # Adam(Adaptive Moment Estimation)

# %%
class Adam:
    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None
        
    def update(self, params, grads):
        if self.m is None:
            self.m, self.v = {}, {}
            for key, val in params.items():
                self.m[key] = np.zeros_like(val)
                self.v[key] = np.zeros_like(val)
                
        self.iter += 1
        lr_t = self.lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)
        
        for key in params.key():
            self.m[key] += (1 - self.beta1) * (grads[key] - self.m[key])
            self.v[key] += (1 - self.beta1) * (grads[key]**2 - self.v[key])
            params[key] -= lr_t * self.m[key] / (np.sqrt(self.v[key]) + np.e**(-7))

# %% [markdown]
# # 過学習

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

#訓練データを減らし過学習を引き起こさせる
x_train = x_train[:300]
t_train = t_train[:300]

def over_fitting(weight_decay_lambda=0):
    #パラメータを増やして過学習を引き起こさせるために層を増やす
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay_lambda)
    optimizer = SGD(lr=0.01)

    max_epochs = 201
    train_size = x_train.shape[0]
    batch_size = 100

    train_loss_list = []
    train_acc_list = []
    test_acc_list = []

    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0

    for i in range(10000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]

        grads = network.gradient(x_batch, t_batch)
        optimizer.update(network.params, grads)

        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            test_acc = network.accuracy(x_test, t_test)
            train_acc_list.append(train_acc)
            test_acc_list.append(test_acc)

            #print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break

    #グラフを描く
    markers = {"train": 'o', "test": 's'}
    x = np.arange(max_epochs)
    plt.plot(x, train_acc_list, marker='o', label="train", markevery=10)
    plt.plot(x, test_acc_list, marker='s', label="test", markevery=10)
    plt.xlabel("epochs")
    plt.ylabel("accuracy")
    plt.ylim(0, 1.0)
    plt.legend(loc="lower right")
    plt.show()

# %%
over_fitting(weight_decay_lambda=0)

# %% [markdown]
# # Weight decay

# %%
#Weight decay(重荷減衰)を0.1に設定
over_fitting(weight_decay_lambda=0.1)

# %% [markdown]
# # Dropout

# %%
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

#学習データはweight decayの時と同じものを用いる

#Dropoutの設定
use_dropout = True
dropout_ratio = 0.2

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                             output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test, epochs=301, mini_batch_size=100, 
                            optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()
train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

#グラフを描く
markers = {"train": 'o', "test": 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label="train", markevery=10)
plt.plot(x, test_acc_list, marker='s', label="test", markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc="lower right")
plt.show()
# Out:
# train loss:2.29310437619
# === epoch:1, train acc:0.116666666667, test acc:0.1027 ===
# train loss:2.27417194887
# train loss:2.30462840334
# train loss:2.30542109234
# === epoch:2, train acc:0.123333333333, test acc:0.1041 ===
# train loss:2.3195643064
# train loss:2.30019368197
# train loss:2.30606756263
# === epoch:3, train acc:0.123333333333, test acc:0.1104 ===
# train loss:2.32516126002
# train loss:2.27689876989
# train loss:2.30495130581
# === epoch:4, train acc:0.126666666667, test acc:0.1109 ===
# train loss:2.27911394584
# train loss:2.29362432211
# train loss:2.27828373797
# === epoch:5, train acc:0.123333333333, test acc:0.1145 ===
# train loss:2.31452217596
# train loss:2.30328812557
# train loss:2.27349619474
# === epoch:6, train acc:0.13, test acc:0.1195 ===
# train loss:2.30986724798
# train loss:2.2927107758
# train loss:2.27242761131
# === epoch:7, train acc:0.126666666667, test acc:0.1217 ===
# train loss:2.29443166117
# train loss:2.30227668452
# train loss:2.29929329629
# === epoch:8, train acc:0.133333333333, test acc:0.1261 ===
# train loss:2.28226814669
# train loss:2.27961150801
# train loss:2.3003114505
# === epoch:9, train acc:0.136666666667, test acc:0.1303 ===
# train loss:2.28105685167
# train loss:2.29728397613
# train loss:2.27304223115
# === epoch:10, train acc:0.14, test acc:0.1315 ===
# train loss:2.29287642929
# train loss:2.27756917925
# train loss:2.29615444002
# === epoch:11, train acc:0.15, test acc:0.1361 ===
# train loss:2.28480523162
# train loss:2.2896465421
# train loss:2.28080932263
# === epoch:12, train acc:0.146666666667, test acc:0.14 ===
# train loss:2.2797790879
# train loss:2.27916953973
# train loss:2.28266008676
# === epoch:13, train acc:0.15, test acc:0.1454 ===
# train loss:2.28230355017
# train loss:2.26508388064
# train loss:2.27098283738
# === epoch:14, train acc:0.16, test acc:0.148 ===
# train loss:2.27295894127
# train loss:2.28222396261
# train loss:2.28061082975
# === epoch:15, train acc:0.163333333333, test acc:0.1504 ===
# train loss:2.27515753934
# train loss:2.2581109972
# train loss:2.28686177557
# === epoch:16, train acc:0.163333333333, test acc:0.1562 ===
# train loss:2.27520076762
# train loss:2.26588511599
# train loss:2.27583205372
# === epoch:17, train acc:0.176666666667, test acc:0.1627 ===
# train loss:2.26973658739
# train loss:2.27940567831
# train loss:2.25896833548
# === epoch:18, train acc:0.183333333333, test acc:0.1693 ===
# train loss:2.27666516888
# train loss:2.26257102398
# train loss:2.26358766006
# === epoch:19, train acc:0.186666666667, test acc:0.1729 ===
# train loss:2.27186246261
# train loss:2.26807801307
# train loss:2.27361139874
# === epoch:20, train acc:0.216666666667, test acc:0.181 ===
# train loss:2.2632710158
# train loss:2.26653646191
# train loss:2.27431388014
# === epoch:21, train acc:0.23, test acc:0.1839 ===
# train loss:2.25662159012
# train loss:2.27827592975
# train loss:2.24229017547
# === epoch:22, train acc:0.24, test acc:0.1873 ===
# train loss:2.26390416321
# train loss:2.26180649887
# train loss:2.26266299283
# === epoch:23, train acc:0.24, test acc:0.1955 ===
# train loss:2.26475401551
# train loss:2.26237368036
# train loss:2.26560150513
# === epoch:24, train acc:0.246666666667, test acc:0.2012 ===
# train loss:2.25124780687
# train loss:2.26686111225
# train loss:2.25843901631
# === epoch:25, train acc:0.25, test acc:0.2053 ===
# train loss:2.25420996844
# train loss:2.26224513394
# train loss:2.25569601675
# === epoch:26, train acc:0.256666666667, test acc:0.2105 ===
# train loss:2.25125868657
# train loss:2.24442789105
# train loss:2.25106727613
# === epoch:27, train acc:0.263333333333, test acc:0.2156 ===
# train loss:2.25800148038
# train loss:2.23961685254
# train loss:2.24973550597
# === epoch:28, train acc:0.266666666667, test acc:0.2228 ===
# train loss:2.25011094142
# train loss:2.23036620837
# train loss:2.25951726915
# === epoch:29, train acc:0.266666666667, test acc:0.2276 ===
# train loss:2.24417833808
# train loss:2.24699829501
# train loss:2.26509416847
# === epoch:30, train acc:0.273333333333, test acc:0.2363 ===
# train loss:2.25806123064
# train loss:2.24495689902
# train loss:2.22162483722
# === epoch:31, train acc:0.286666666667, test acc:0.2418 ===
# train loss:2.24020827601
# train loss:2.24610864307
# train loss:2.23527498453
# === epoch:32, train acc:0.296666666667, test acc:0.2461 ===
# train loss:2.25178541681
# train loss:2.23121147114
# train loss:2.25272714495
# === epoch:33, train acc:0.306666666667, test acc:0.2529 ===
# train loss:2.24785187061
# train loss:2.24966634042
# train loss:2.24684100702
# === epoch:34, train acc:0.313333333333, test acc:0.2585 ===
# train loss:2.24884763128
# train loss:2.23200740296
# train loss:2.22465694049
# === epoch:35, train acc:0.316666666667, test acc:0.2622 ===
# train loss:2.24734062727
# train loss:2.26508166241
# train loss:2.23959476522
# === epoch:36, train acc:0.33, test acc:0.2696 ===
# train loss:2.23536684672
# train loss:2.23077175441
# train loss:2.23336673574
# === epoch:37, train acc:0.336666666667, test acc:0.275 ===
# train loss:2.2123032067
# train loss:2.24111396283
# train loss:2.24953735112
# === epoch:38, train acc:0.346666666667, test acc:0.2756 ===
# train loss:2.22230836481
# train loss:2.24163859601
# train loss:2.22800612249
# === epoch:39, train acc:0.346666666667, test acc:0.2804 ===
# train loss:2.2349837438
# train loss:2.23835433458
# train loss:2.22687843295
# === epoch:40, train acc:0.35, test acc:0.2793 ===
# train loss:2.24150112719
# train loss:2.22786422282
# train loss:2.23877473366
# === epoch:41, train acc:0.356666666667, test acc:0.2829 ===
# train loss:2.21600318318
# train loss:2.24263743676
# train loss:2.23965768592
# === epoch:42, train acc:0.356666666667, test acc:0.2874 ===
# train loss:2.23667276075
# train loss:2.21230968356
# train loss:2.2201251662
# === epoch:43, train acc:0.353333333333, test acc:0.2888 ===
# train loss:2.23290704507
# train loss:2.20977157959
# train loss:2.22525705988
# === epoch:44, train acc:0.366666666667, test acc:0.2943 ===
# train loss:2.21798626404
# train loss:2.23240380949
# train loss:2.22055386857
# === epoch:45, train acc:0.376666666667, test acc:0.303 ===
# train loss:2.22192828651
# train loss:2.18955993156
# train loss:2.2157624071
# === epoch:46, train acc:0.383333333333, test acc:0.3039 ===
# train loss:2.2066167313
# train loss:2.24130614672
# train loss:2.24029723754
# === epoch:47, train acc:0.383333333333, test acc:0.304 ===
# train loss:2.22722343946
# train loss:2.20852375458
# train loss:2.23570022387
# === epoch:48, train acc:0.37, test acc:0.3064 ===
# train loss:2.21268628922
# train loss:2.2134086898
# train loss:2.22940738334
# === epoch:49, train acc:0.38, test acc:0.3115 ===
# train loss:2.22811001837
# train loss:2.21793046104
# train loss:2.21094443055
# === epoch:50, train acc:0.38, test acc:0.3138 ===
# train loss:2.19334510723
# train loss:2.20849642796
# train loss:2.21468825963
# === epoch:51, train acc:0.383333333333, test acc:0.3136 ===
# train loss:2.17273134808
# train loss:2.22763045906
# train loss:2.20660845306
# === epoch:52, train acc:0.383333333333, test acc:0.3153 ===
# train loss:2.24226062723
# train loss:2.18744735273
# train loss:2.20799523845
# === epoch:53, train acc:0.383333333333, test acc:0.3174 ===
# train loss:2.19839898589
# train loss:2.22119512419
# train loss:2.17273181999
# === epoch:54, train acc:0.39, test acc:0.3171 ===
# train loss:2.18941193822
# train loss:2.21679210663
# train loss:2.22513184802
# === epoch:55, train acc:0.396666666667, test acc:0.3229 ===
# train loss:2.19201472759
# train loss:2.19247203738
# train loss:2.18733543831
# === epoch:56, train acc:0.406666666667, test acc:0.3267 ===
# train loss:2.18282442756
# train loss:2.19072357127
# train loss:2.17449995175
# === epoch:57, train acc:0.39, test acc:0.3245 ===
# train loss:2.2154120808
# train loss:2.23358087089
# train loss:2.21011360845
# === epoch:58, train acc:0.403333333333, test acc:0.3288 ===
# train loss:2.18356494447
# train loss:2.19219997838
# train loss:2.19311341218
# === epoch:59, train acc:0.403333333333, test acc:0.3301 ===
# train loss:2.19288431859
# train loss:2.20874480328
# train loss:2.18800675582
# === epoch:60, train acc:0.41, test acc:0.3331 ===
# train loss:2.20447900825
# train loss:2.17523110441
# train loss:2.15329843502
# === epoch:61, train acc:0.386666666667, test acc:0.3216 ===
# train loss:2.134511628
# train loss:2.18092829098
# train loss:2.19793775441
# === epoch:62, train acc:0.383333333333, test acc:0.3207 ===
# train loss:2.19310495393
# train loss:2.16823418578
# train loss:2.17984061759
# === epoch:63, train acc:0.393333333333, test acc:0.3238 ===
# train loss:2.18334570601
# train loss:2.17565434695
# train loss:2.20966856796
# === epoch:64, train acc:0.39, test acc:0.3281 ===
# train loss:2.16149009867
# train loss:2.14232972573
# train loss:2.17553302678
# === epoch:65, train acc:0.396666666667, test acc:0.3312 ===
# train loss:2.18468875099
# train loss:2.17257367626
# train loss:2.18474805128
# === epoch:66, train acc:0.39, test acc:0.3262 ===
# train loss:2.16250378529
# train loss:2.1744127341
# train loss:2.17370578502
# === epoch:67, train acc:0.396666666667, test acc:0.3274 ===
# train loss:2.18713288749
# train loss:2.15800860799
# train loss:2.14903484892
# === epoch:68, train acc:0.393333333333, test acc:0.3292 ===
# train loss:2.16606546
# train loss:2.19370453434
# train loss:2.17776945041
# === epoch:69, train acc:0.396666666667, test acc:0.3298 ===
# train loss:2.14889934836
# train loss:2.14464209854
# train loss:2.16905387336
# === epoch:70, train acc:0.393333333333, test acc:0.3314 ===
# train loss:2.13888126567
# train loss:2.17774639576
# train loss:2.10647757532
# === epoch:71, train acc:0.396666666667, test acc:0.3309 ===
# train loss:2.18367375184
# train loss:2.18057939991
# train loss:2.15994552795
# === epoch:72, train acc:0.396666666667, test acc:0.3348 ===
# train loss:2.16592650619
# train loss:2.14627709001
# train loss:2.1223788369
# === epoch:73, train acc:0.396666666667, test acc:0.3356 ===
# train loss:2.1511833745
# train loss:2.1987317205
# train loss:2.15886407412
# === epoch:74, train acc:0.403333333333, test acc:0.3396 ===
# train loss:2.06434335991
# train loss:2.14801375127
# train loss:2.12822656906
# === epoch:75, train acc:0.4, test acc:0.3418 ===
# train loss:2.11767278725
# train loss:2.17411520525
# train loss:2.12533936571
# === epoch:76, train acc:0.406666666667, test acc:0.3444 ===
# train loss:2.15161132575
# train loss:2.10275972202
# train loss:2.09310279515
# === epoch:77, train acc:0.406666666667, test acc:0.3475 ===
# train loss:2.13596136668
# train loss:2.0886615209
# train loss:2.13491860055
# === epoch:78, train acc:0.403333333333, test acc:0.3451 ===
# train loss:2.12099532263
# train loss:2.18633206959
# train loss:2.14594427016
# === epoch:79, train acc:0.413333333333, test acc:0.3523 ===
# train loss:2.10238742382
# train loss:2.16123642295
# train loss:2.13360550749
# === epoch:80, train acc:0.416666666667, test acc:0.3535 ===
# train loss:2.11288668408
# train loss:2.15083350896
# train loss:2.14148223544
# === epoch:81, train acc:0.416666666667, test acc:0.3543 ===
# train loss:2.0923230745
# train loss:2.10125964929
# train loss:2.11764218054
# === epoch:82, train acc:0.41, test acc:0.3477 ===
# train loss:2.08283971063
# train loss:2.14465345671
# train loss:2.14059717474
# === epoch:83, train acc:0.406666666667, test acc:0.3515 ===
# train loss:2.10895705952
# train loss:2.09607251097
# train loss:2.08714717827
# === epoch:84, train acc:0.416666666667, test acc:0.3521 ===
# train loss:2.09641030216
# train loss:2.14872737381
# train loss:2.13728984405
# === epoch:85, train acc:0.423333333333, test acc:0.3573 ===
# train loss:2.08677840828
# train loss:2.09487808057
# train loss:2.13834932538
# === epoch:86, train acc:0.42, test acc:0.3607 ===
# train loss:2.08328076175
# train loss:2.08106063974
# train loss:2.09244459015
# === epoch:87, train acc:0.413333333333, test acc:0.3555 ===
# train loss:2.15026820707
# train loss:2.13286564598
# train loss:2.09051851826
# === epoch:88, train acc:0.41, test acc:0.3578 ===
# train loss:2.1046401626
# train loss:2.11148493846
# train loss:2.1032151147
# === epoch:89, train acc:0.406666666667, test acc:0.3582 ===
# train loss:2.04322312582
# train loss:2.07350820584
# train loss:2.06698704568
# === epoch:90, train acc:0.423333333333, test acc:0.3609 ===
# train loss:2.14470717733
# train loss:2.09549173418
# train loss:2.0562798474
# === epoch:91, train acc:0.436666666667, test acc:0.3649 ===
# train loss:2.09798706628
# train loss:2.07281889179
# train loss:1.99806957245
# === epoch:92, train acc:0.416666666667, test acc:0.3576 ===
# train loss:2.09249717253
# train loss:2.08727668309
# train loss:2.1109307278
# === epoch:93, train acc:0.433333333333, test acc:0.3645 ===
# train loss:2.12965177529
# train loss:2.03848647387
# train loss:2.09557081103
# === epoch:94, train acc:0.443333333333, test acc:0.3683 ===
# train loss:2.09767247859
# train loss:2.07083733083
# train loss:2.03053072138
# === epoch:95, train acc:0.446666666667, test acc:0.3734 ===
# train loss:2.08188769195
# train loss:2.06088893522
# train loss:2.05916937268
# === epoch:96, train acc:0.443333333333, test acc:0.3774 ===
# train loss:2.06557346801
# train loss:2.02469128759
# train loss:2.05953343254
# === epoch:97, train acc:0.443333333333, test acc:0.3797 ===
# train loss:2.1044949224
# train loss:2.07937382108
# train loss:2.0201921965
# === epoch:98, train acc:0.443333333333, test acc:0.3811 ===
# train loss:1.98105746263
# train loss:2.03329469628
# train loss:1.97959534104
# === epoch:99, train acc:0.446666666667, test acc:0.3775 ===
# train loss:2.02211510444
# train loss:1.97475308936
# train loss:2.03216517055
# === epoch:100, train acc:0.446666666667, test acc:0.3751 ===
# train loss:1.99782377408
# train loss:2.00410684471
# train loss:2.03268139797
# === epoch:101, train acc:0.44, test acc:0.3752 ===
# train loss:2.01612981635
# train loss:2.06494125226
# train loss:2.01421272671
# === epoch:102, train acc:0.443333333333, test acc:0.3754 ===
# train loss:2.01056498449
# train loss:2.04871335297
# train loss:2.02470701644
# === epoch:103, train acc:0.44, test acc:0.3755 ===
# train loss:2.01197077842
# train loss:2.07298367991
# train loss:2.04528467275
# === epoch:104, train acc:0.436666666667, test acc:0.3761 ===
# train loss:2.0966711814
# train loss:2.0050351499
# train loss:1.97982877196
# === epoch:105, train acc:0.45, test acc:0.3805 ===
# train loss:2.07430630653
# train loss:1.97708520877
# train loss:2.01641197786
# === epoch:106, train acc:0.453333333333, test acc:0.3832 ===
# train loss:2.04906811587
# train loss:1.94710646867
# train loss:1.94711881373
# === epoch:107, train acc:0.456666666667, test acc:0.3827 ===
# train loss:2.05325905706
# train loss:2.02565907728
# train loss:1.99900777661
# === epoch:108, train acc:0.453333333333, test acc:0.3843 ===
# train loss:2.00450012107
# train loss:1.95807967317
# train loss:2.08398790888
# === epoch:109, train acc:0.466666666667, test acc:0.3899 ===
# train loss:1.98268333463
# train loss:2.0191009543
# train loss:2.02502082913
# === epoch:110, train acc:0.47, test acc:0.3916 ===
# train loss:1.99141343249
# train loss:1.97764761592
# train loss:1.95241461105
# === epoch:111, train acc:0.48, test acc:0.3922 ===
# train loss:1.98500495073
# train loss:1.98417495411
# train loss:2.00227113236
# === epoch:112, train acc:0.473333333333, test acc:0.3939 ===
# train loss:1.91745474384
# train loss:1.94491798292
# train loss:1.97857050314
# === epoch:113, train acc:0.47, test acc:0.3937 ===
# train loss:1.95463409458
# train loss:1.95932213473
# train loss:1.99692344358
# === epoch:114, train acc:0.463333333333, test acc:0.3949 ===
# train loss:1.92439789468
# train loss:1.97471597944
# train loss:1.98988830495
# === epoch:115, train acc:0.47, test acc:0.3929 ===
# train loss:2.04729537495
# train loss:2.03059154652
# train loss:2.00471618084
# === epoch:116, train acc:0.473333333333, test acc:0.3985 ===
# train loss:1.89896438247
# train loss:1.95508574876
# train loss:1.968577723
# === epoch:117, train acc:0.476666666667, test acc:0.3988 ===
# train loss:1.88712072608
# train loss:1.98900489735
# train loss:1.9438392194
# === epoch:118, train acc:0.48, test acc:0.4011 ===
# train loss:1.92647397053
# train loss:1.94970016102
# train loss:1.9061090062
# === epoch:119, train acc:0.476666666667, test acc:0.3998 ===
# train loss:2.01428187251
# train loss:1.90352848977
# train loss:1.85629663754
# === epoch:120, train acc:0.476666666667, test acc:0.4016 ===
# train loss:1.94691926893
# train loss:1.93882732146
# train loss:1.95806129379
# === epoch:121, train acc:0.483333333333, test acc:0.4043 ===
# train loss:1.94020818688
# train loss:1.92914343654
# train loss:1.90122758149
# === epoch:122, train acc:0.48, test acc:0.4049 ===
# train loss:1.81311191024
# train loss:1.88327775478
# train loss:1.80489886418
# === epoch:123, train acc:0.48, test acc:0.4037 ===
# train loss:1.98573233727
# train loss:1.87721684007
# train loss:1.96220231975
# === epoch:124, train acc:0.48, test acc:0.4055 ===
# train loss:1.85240017089
# train loss:1.93397036374
# train loss:1.8974590829
# === epoch:125, train acc:0.483333333333, test acc:0.4079 ===
# train loss:1.89618897795
# train loss:1.80173916871
# train loss:1.81869808424
# === epoch:126, train acc:0.48, test acc:0.4066 ===
# train loss:1.96954346556
# train loss:1.87872256495
# train loss:1.80756321276
# === epoch:127, train acc:0.476666666667, test acc:0.4073 ===
# train loss:1.88488384403
# train loss:1.91904850685
# train loss:1.84605151642
# === epoch:128, train acc:0.483333333333, test acc:0.4081 ===
# train loss:1.94605349242
# train loss:1.91832849768
# train loss:1.91058679192
# === epoch:129, train acc:0.48, test acc:0.4085 ===
# train loss:1.90544504472
# train loss:1.91944680373
# train loss:1.80265318764
# === epoch:130, train acc:0.476666666667, test acc:0.4084 ===
# train loss:1.82822199016
# train loss:1.86736626232
# train loss:1.86352959653
# === epoch:131, train acc:0.48, test acc:0.4089 ===
# train loss:1.92486751466
# train loss:1.83430676289
# train loss:1.85219346886
# === epoch:132, train acc:0.48, test acc:0.4088 ===
# train loss:1.86651414381
# train loss:1.85313960872
# train loss:1.68566095891
# === epoch:133, train acc:0.483333333333, test acc:0.4102 ===
# train loss:1.91484498698
# train loss:1.86529124649
# train loss:1.76246956671
# === epoch:134, train acc:0.486666666667, test acc:0.4116 ===
# train loss:1.88116502505
# train loss:1.92674090769
# train loss:1.84535174579
# === epoch:135, train acc:0.493333333333, test acc:0.4143 ===
# train loss:1.79350194368
# train loss:1.80710670615
# train loss:1.82980316886
# === epoch:136, train acc:0.506666666667, test acc:0.4164 ===
# train loss:1.90139609739
# train loss:1.78447581117
# train loss:1.81006161096
# === epoch:137, train acc:0.52, test acc:0.4186 ===
# train loss:1.79538862143
# train loss:1.9284836683
# train loss:1.85114932997
# === epoch:138, train acc:0.516666666667, test acc:0.4201 ===
# train loss:1.7081933841
# train loss:1.8901400817
# train loss:1.84211685237
# === epoch:139, train acc:0.516666666667, test acc:0.4227 ===
# train loss:1.86739805724
# train loss:1.84795515414
# train loss:1.88935577875
# === epoch:140, train acc:0.526666666667, test acc:0.4283 ===
# train loss:1.74722920686
# train loss:1.77279352845
# train loss:1.88187961783
# === epoch:141, train acc:0.516666666667, test acc:0.4241 ===
# train loss:1.77025772062
# train loss:1.85312951477
# train loss:1.64253259449
# === epoch:142, train acc:0.516666666667, test acc:0.4206 ===
# train loss:1.78264303109
# train loss:1.6748135122
# train loss:1.74354786949
# === epoch:143, train acc:0.516666666667, test acc:0.4231 ===
# train loss:1.77947813711
# train loss:1.75952888704
# train loss:1.83005884389
# === epoch:144, train acc:0.52, test acc:0.4259 ===
# train loss:1.751196441
# train loss:1.79552887657
# train loss:1.81523116639
# === epoch:145, train acc:0.523333333333, test acc:0.4275 ===
# train loss:1.76250223741
# train loss:1.80325541726
# train loss:1.74911284334
# === epoch:146, train acc:0.523333333333, test acc:0.4309 ===
# train loss:1.73408795251
# train loss:1.75572096438
# train loss:1.86474457759
# === epoch:147, train acc:0.526666666667, test acc:0.4338 ===
# train loss:1.69632986502
# train loss:1.77398169805
# train loss:1.794323584
# === epoch:148, train acc:0.526666666667, test acc:0.4347 ===
# train loss:1.65564469109
# train loss:1.76038850297
# train loss:1.70997750279
# === epoch:149, train acc:0.53, test acc:0.4348 ===
# train loss:1.70325729124
# train loss:1.75174720219
# train loss:1.66821803625
# === epoch:150, train acc:0.526666666667, test acc:0.4331 ===
# train loss:1.70693720457
# train loss:1.7796914244
# train loss:1.73148186303
# === epoch:151, train acc:0.523333333333, test acc:0.4329 ===
# train loss:1.68654345807
# train loss:1.70907387866
# train loss:1.70581779004
# === epoch:152, train acc:0.526666666667, test acc:0.4325 ===
# train loss:1.69735084618
# train loss:1.69566129328
# train loss:1.74879845713
# === epoch:153, train acc:0.53, test acc:0.4321 ===
# train loss:1.68749547902
# train loss:1.63942244132
# train loss:1.77345032679
# === epoch:154, train acc:0.54, test acc:0.4377 ===
# train loss:1.80403296529
# train loss:1.6924062557
# train loss:1.85555596015
# === epoch:155, train acc:0.543333333333, test acc:0.4397 ===
# train loss:1.73325801024
# train loss:1.66374038999
# train loss:1.71081418513
# === epoch:156, train acc:0.533333333333, test acc:0.4365 ===
# train loss:1.70767051836
# train loss:1.614398836
# train loss:1.73567807368
# === epoch:157, train acc:0.543333333333, test acc:0.4395 ===
# train loss:1.56868704716
# train loss:1.69310563627
# train loss:1.68241037697
# === epoch:158, train acc:0.54, test acc:0.4368 ===
# train loss:1.68978824658
# train loss:1.70780645422
# train loss:1.67835224575
# === epoch:159, train acc:0.536666666667, test acc:0.4408 ===
# train loss:1.63713797715
# train loss:1.73252079306
# train loss:1.67145026824
# === epoch:160, train acc:0.55, test acc:0.445 ===
# train loss:1.58888749352
# train loss:1.75389590259
# train loss:1.77489563811
# === epoch:161, train acc:0.55, test acc:0.4474 ===
# train loss:1.63740560899
# train loss:1.61642969789
# train loss:1.65319075026
# === epoch:162, train acc:0.55, test acc:0.4484 ===
# train loss:1.68556514979
# train loss:1.80923506014
# train loss:1.70449400508
# === epoch:163, train acc:0.55, test acc:0.4495 ===
# train loss:1.62954152278
# train loss:1.58424311568
# train loss:1.68183612093
# === epoch:164, train acc:0.56, test acc:0.4509 ===
# train loss:1.69631384079
# train loss:1.75337399784
# train loss:1.64140294338
# === epoch:165, train acc:0.566666666667, test acc:0.4536 ===
# train loss:1.70674423107
# train loss:1.51364907039
# train loss:1.741343941
# === epoch:166, train acc:0.56, test acc:0.4542 ===
# train loss:1.73568376071
# train loss:1.52487450212
# train loss:1.56185931584
# === epoch:167, train acc:0.56, test acc:0.4548 ===
# train loss:1.46545891736
# train loss:1.54435996283
# train loss:1.64351914496
# === epoch:168, train acc:0.56, test acc:0.4571 ===
# train loss:1.67055305671
# train loss:1.56585706467
# train loss:1.63175632383
# === epoch:169, train acc:0.566666666667, test acc:0.4587 ===
# train loss:1.51209187489
# train loss:1.58951222908
# train loss:1.57282258815
# === epoch:170, train acc:0.573333333333, test acc:0.4578 ===
# train loss:1.49756669957
# train loss:1.6640389563
# train loss:1.63583853231
# === epoch:171, train acc:0.57, test acc:0.4572 ===
# train loss:1.64324973912
# train loss:1.5599219346
# train loss:1.67635924712
# === epoch:172, train acc:0.566666666667, test acc:0.4572 ===
# train loss:1.6387475742
# train loss:1.64937537537
# train loss:1.61757589125
# === epoch:173, train acc:0.576666666667, test acc:0.4644 ===
# train loss:1.72195869224
# train loss:1.51959556481
# train loss:1.4576626707
# === epoch:174, train acc:0.576666666667, test acc:0.4636 ===
# train loss:1.58905556865
# train loss:1.64178366096
# train loss:1.49910351732
# === epoch:175, train acc:0.58, test acc:0.4616 ===
# train loss:1.54531812221
# train loss:1.60176473245
# train loss:1.58341004593
# === epoch:176, train acc:0.576666666667, test acc:0.4625 ===
# train loss:1.6121115461
# train loss:1.51879184341
# train loss:1.54348620596
# === epoch:177, train acc:0.573333333333, test acc:0.4627 ===
# train loss:1.64137051094
# train loss:1.54466817909
# train loss:1.69960512486
# === epoch:178, train acc:0.583333333333, test acc:0.4682 ===
# train loss:1.56116401538
# train loss:1.50391526411
# train loss:1.43275086244
# === epoch:179, train acc:0.58, test acc:0.4645 ===
# train loss:1.58148902663
# train loss:1.45686408026
# train loss:1.56104322574
# === epoch:180, train acc:0.586666666667, test acc:0.4665 ===
# train loss:1.56192606555
# train loss:1.55389676354
# train loss:1.53243873316
# === epoch:181, train acc:0.59, test acc:0.4694 ===
# train loss:1.55756194818
# train loss:1.46743896162
# train loss:1.56842794201
# === epoch:182, train acc:0.59, test acc:0.4709 ===
# train loss:1.67244602288
# train loss:1.41398889631
# train loss:1.67847972891
# === epoch:183, train acc:0.593333333333, test acc:0.4708 ===
# train loss:1.5557861254
# train loss:1.46732845661
# train loss:1.5188607326
# === epoch:184, train acc:0.596666666667, test acc:0.4719 ===
# train loss:1.5337172144
# train loss:1.5221938326
# train loss:1.5644618408
# === epoch:185, train acc:0.6, test acc:0.4751 ===
# train loss:1.45906358971
# train loss:1.47797756337
# train loss:1.59989723151
# === epoch:186, train acc:0.596666666667, test acc:0.4771 ===
# train loss:1.53360223074
# train loss:1.61242882669
# train loss:1.5391906797
# === epoch:187, train acc:0.6, test acc:0.4752 ===
# train loss:1.61781951578
# train loss:1.50895667356
# train loss:1.39731067938
# === epoch:188, train acc:0.59, test acc:0.4756 ===
# train loss:1.58821707777
# train loss:1.49991364578
# train loss:1.49197674743
# === epoch:189, train acc:0.576666666667, test acc:0.4732 ===
# train loss:1.62591868331
# train loss:1.51659627907
# train loss:1.57786544143
# === epoch:190, train acc:0.593333333333, test acc:0.4783 ===
# train loss:1.48761921606
# train loss:1.58396856799
# train loss:1.52629352048
# === epoch:191, train acc:0.59, test acc:0.479 ===
# train loss:1.34516946917
# train loss:1.46883911839
# train loss:1.49895114439
# === epoch:192, train acc:0.593333333333, test acc:0.4808 ===
# train loss:1.62166851827
# train loss:1.49268813323
# train loss:1.48054593678
# === epoch:193, train acc:0.6, test acc:0.4821 ===
# train loss:1.56397696021
# train loss:1.33818283748
# train loss:1.44643552887
# === epoch:194, train acc:0.606666666667, test acc:0.4811 ===
# train loss:1.55034858904
# train loss:1.54925358244
# train loss:1.46081630527
# === epoch:195, train acc:0.603333333333, test acc:0.4827 ===
# train loss:1.45651835961
# train loss:1.50065051796
# train loss:1.46752518324
# === epoch:196, train acc:0.616666666667, test acc:0.4843 ===
# train loss:1.49149435167
# train loss:1.36707147525
# train loss:1.48361647669
# === epoch:197, train acc:0.606666666667, test acc:0.4821 ===
# train loss:1.51105812031
# train loss:1.61877066169
# train loss:1.47386545902
# === epoch:198, train acc:0.613333333333, test acc:0.484 ===
# train loss:1.51487544649
# train loss:1.35737782875
# train loss:1.59964204317
# === epoch:199, train acc:0.61, test acc:0.4873 ===
# train loss:1.53638535642
# train loss:1.57619713741
# train loss:1.45977608911
# === epoch:200, train acc:0.62, test acc:0.49 ===
# train loss:1.43084685278
# train loss:1.39042374052
# train loss:1.4288179885
# === epoch:201, train acc:0.606666666667, test acc:0.4896 ===
# train loss:1.46745101745
# train loss:1.36467915368
# train loss:1.50623410686
# === epoch:202, train acc:0.613333333333, test acc:0.4883 ===
# train loss:1.46834462156
# train loss:1.45774517953
# train loss:1.38165901796
# === epoch:203, train acc:0.613333333333, test acc:0.488 ===
# train loss:1.5155955154
# train loss:1.42765039346
# train loss:1.38312641206
# === epoch:204, train acc:0.61, test acc:0.4881 ===
# train loss:1.57396086641
# train loss:1.42280517804
# train loss:1.51623425194
# === epoch:205, train acc:0.613333333333, test acc:0.4914 ===
# train loss:1.3003946075
# train loss:1.43634755859
# train loss:1.43532477368
# === epoch:206, train acc:0.616666666667, test acc:0.491 ===
# train loss:1.44228557136
# train loss:1.48992561534
# train loss:1.42004361017
# === epoch:207, train acc:0.626666666667, test acc:0.4941 ===
# train loss:1.35699288823
# train loss:1.40295083741
# train loss:1.49148750513
# === epoch:208, train acc:0.616666666667, test acc:0.492 ===
# train loss:1.42758083557
# train loss:1.43576415111
# train loss:1.34147802267
# === epoch:209, train acc:0.623333333333, test acc:0.4929 ===
# train loss:1.46360215086
# train loss:1.46596779774
# train loss:1.24060254052
# === epoch:210, train acc:0.606666666667, test acc:0.4916 ===
# train loss:1.40945194652
# train loss:1.35005016491
# train loss:1.38785060057
# === epoch:211, train acc:0.61, test acc:0.49 ===
# train loss:1.2678949102
# train loss:1.33654631978
# train loss:1.2657587402
# === epoch:212, train acc:0.613333333333, test acc:0.4924 ===
# train loss:1.40162335433
# train loss:1.32618455644
# train loss:1.481757414
# === epoch:213, train acc:0.606666666667, test acc:0.4903 ===
# train loss:1.23342750285
# train loss:1.33844837645
# train loss:1.32288500439
# === epoch:214, train acc:0.61, test acc:0.4902 ===
# train loss:1.40318437983
# train loss:1.55600723617
# train loss:1.33951944552
# === epoch:215, train acc:0.616666666667, test acc:0.4945 ===
# train loss:1.37651437396
# train loss:1.46634694046
# train loss:1.43263280128
# === epoch:216, train acc:0.616666666667, test acc:0.4962 ===
# train loss:1.46092061114
# train loss:1.41450721012
# train loss:1.34756198202
# === epoch:217, train acc:0.62, test acc:0.4979 ===
# train loss:1.3649199571
# train loss:1.36807772322
# train loss:1.43661316095
# === epoch:218, train acc:0.62, test acc:0.497 ===
# train loss:1.36443202436
# train loss:1.43546804702
# train loss:1.44662497958
# === epoch:219, train acc:0.626666666667, test acc:0.4989 ===
# train loss:1.38470550044
# train loss:1.3105995561
# train loss:1.40111832439
# === epoch:220, train acc:0.63, test acc:0.5002 ===
# train loss:1.06680380669
# train loss:1.29991241986
# train loss:1.31879044535
# === epoch:221, train acc:0.633333333333, test acc:0.5005 ===
# train loss:1.23361432059
# train loss:1.38992913046
# train loss:1.27697545452
# === epoch:222, train acc:0.626666666667, test acc:0.4993 ===
# train loss:1.3199868155
# train loss:1.42800719015
# train loss:1.2886307907
# === epoch:223, train acc:0.64, test acc:0.502 ===
# train loss:1.31785634266
# train loss:1.21515766888
# train loss:1.18570982695
# === epoch:224, train acc:0.636666666667, test acc:0.5007 ===
# train loss:1.43272526134
# train loss:1.33168271122
# train loss:1.21532592524
# === epoch:225, train acc:0.62, test acc:0.5012 ===
# train loss:1.33849237962
# train loss:1.35892858832
# train loss:1.34097248537
# === epoch:226, train acc:0.62, test acc:0.502 ===
# train loss:1.36793158084
# train loss:1.20274827392
# train loss:1.23889930959
# === epoch:227, train acc:0.623333333333, test acc:0.5024 ===
# train loss:1.34959270266
# train loss:1.27996764359
# train loss:1.24654038843
# === epoch:228, train acc:0.623333333333, test acc:0.5034 ===
# train loss:1.32867557625
# train loss:1.32409449106
# train loss:1.37620348021
# === epoch:229, train acc:0.62, test acc:0.5045 ===
# train loss:1.25543106739
# train loss:1.39116616763
# train loss:1.29562011043
# === epoch:230, train acc:0.613333333333, test acc:0.5051 ===
# train loss:1.36788587859
# train loss:1.26945676189
# train loss:1.26976308695
# === epoch:231, train acc:0.616666666667, test acc:0.506 ===
# train loss:1.26870833225
# train loss:1.22466578414
# train loss:1.18599323116
# === epoch:232, train acc:0.62, test acc:0.5055 ===
# train loss:1.28918058241
# train loss:1.28818976209
# train loss:1.12955458148
# === epoch:233, train acc:0.616666666667, test acc:0.507 ===
# train loss:1.28174947732
# train loss:1.22231741698
# train loss:1.32512725949
# === epoch:234, train acc:0.613333333333, test acc:0.5065 ===
# train loss:1.23208595394
# train loss:1.20658034046
# train loss:1.18085410808
# === epoch:235, train acc:0.62, test acc:0.5064 ===
# train loss:1.15004698768
# train loss:1.14405346759
# train loss:1.37909538009
# === epoch:236, train acc:0.62, test acc:0.508 ===
# train loss:1.16906562139
# train loss:1.25331000606
# train loss:1.35396328851
# === epoch:237, train acc:0.62, test acc:0.5101 ===
# train loss:1.16721997774
# train loss:1.19475083185
# train loss:1.32691453377
# === epoch:238, train acc:0.613333333333, test acc:0.5068 ===
# train loss:1.26778518749
# train loss:1.32842022388
# train loss:1.30566176827
# === epoch:239, train acc:0.616666666667, test acc:0.507 ===
# train loss:1.17733209589
# train loss:1.13689878634
# train loss:1.16957577694
# === epoch:240, train acc:0.63, test acc:0.5107 ===
# train loss:1.19094592583
# train loss:1.16120749789
# train loss:1.20682641121
# === epoch:241, train acc:0.64, test acc:0.5107 ===
# train loss:1.21696820606
# train loss:1.31310188584
# train loss:1.21119805081
# === epoch:242, train acc:0.643333333333, test acc:0.5134 ===
# train loss:1.20322361937
# train loss:1.26732224275
# train loss:1.13673688835
# === epoch:243, train acc:0.636666666667, test acc:0.5102 ===
# train loss:1.41108655609
# train loss:1.35972053415
# train loss:1.29259314689
# === epoch:244, train acc:0.643333333333, test acc:0.5118 ===
# train loss:1.20289619439
# train loss:1.33932650116
# train loss:1.07155063492
# === epoch:245, train acc:0.643333333333, test acc:0.5112 ===
# train loss:1.10853420907
# train loss:1.18423777774
# train loss:1.1317954418
# === epoch:246, train acc:0.643333333333, test acc:0.5115 ===
# train loss:1.3011589187
# train loss:1.22507065918
# train loss:1.10234353162
# === epoch:247, train acc:0.653333333333, test acc:0.5142 ===
# train loss:1.11559431763
# train loss:1.27561366103
# train loss:1.18665487576
# === epoch:248, train acc:0.653333333333, test acc:0.5146 ===
# train loss:1.27303544638
# train loss:1.19329161901
# train loss:1.31811694442
# === epoch:249, train acc:0.66, test acc:0.5154 ===
# train loss:1.33709820732
# train loss:1.10058582241
# train loss:1.18910688545
# === epoch:250, train acc:0.653333333333, test acc:0.5173 ===
# train loss:1.150249298
# train loss:1.24167824106
# train loss:1.13699265324
# === epoch:251, train acc:0.643333333333, test acc:0.5183 ===
# train loss:1.14391373139
# train loss:1.17779671327
# train loss:1.07161552779
# === epoch:252, train acc:0.64, test acc:0.5159 ===
# train loss:1.09526210085
# train loss:1.22902860023
# train loss:1.1739905816
# === epoch:253, train acc:0.643333333333, test acc:0.5194 ===
# train loss:1.19589405188
# train loss:1.20487687134
# train loss:1.12785847839
# === epoch:254, train acc:0.64, test acc:0.5192 ===
# train loss:1.18713126876
# train loss:1.21511321606
# train loss:1.22187732444
# === epoch:255, train acc:0.633333333333, test acc:0.519 ===
# train loss:1.24967723334
# train loss:1.09757021815
# train loss:1.14259348318
# === epoch:256, train acc:0.636666666667, test acc:0.5186 ===
# train loss:1.19134750627
# train loss:1.32660984191
# train loss:1.15643078537
# === epoch:257, train acc:0.646666666667, test acc:0.5214 ===
# train loss:1.15808328339
# train loss:1.02258152994
# train loss:0.980790712379
# === epoch:258, train acc:0.646666666667, test acc:0.5184 ===
# train loss:1.18099000193
# train loss:1.21030325788
# train loss:0.981232446557
# === epoch:259, train acc:0.643333333333, test acc:0.5194 ===
# train loss:1.10771117471
# train loss:1.03685088885
# train loss:1.07136016524
# === epoch:260, train acc:0.64, test acc:0.5203 ===
# train loss:1.11753767177
# train loss:1.1307971492
# train loss:1.12356315502
# === epoch:261, train acc:0.64, test acc:0.5195 ===
# train loss:1.14419438323
# train loss:1.26789242176
# train loss:1.1342020296
# === epoch:262, train acc:0.643333333333, test acc:0.5207 ===
# train loss:1.22235396807
# train loss:1.08142065304
# train loss:1.06714291572
# === epoch:263, train acc:0.65, test acc:0.5221 ===
# train loss:1.07182112611
# train loss:1.08069113668
# train loss:1.17858461817
# === epoch:264, train acc:0.65, test acc:0.5209 ===
# train loss:1.07442189627
# train loss:1.07643022399
# train loss:1.15432540863
# === epoch:265, train acc:0.65, test acc:0.5217 ===
# train loss:1.09569444267
# train loss:1.15588534808
# train loss:1.07910561891
# === epoch:266, train acc:0.643333333333, test acc:0.5184 ===
# train loss:0.934880138536
# train loss:1.23146004
# train loss:1.08441584244
# === epoch:267, train acc:0.646666666667, test acc:0.519 ===
# train loss:1.09606520145
# train loss:1.0387956331
# train loss:1.1196531788
# === epoch:268, train acc:0.646666666667, test acc:0.5184 ===
# train loss:1.1484852457
# train loss:1.13292741366
# train loss:0.9099112458
# === epoch:269, train acc:0.646666666667, test acc:0.5226 ===
# train loss:1.116839383
# train loss:1.08733437299
# train loss:0.926376164375
# === epoch:270, train acc:0.653333333333, test acc:0.5249 ===
# train loss:0.998571933277
# train loss:1.00002373751
# train loss:0.969686331014
# === epoch:271, train acc:0.653333333333, test acc:0.5282 ===
# train loss:1.08222571678
# train loss:1.04226748778
# train loss:1.06704118897
# === epoch:272, train acc:0.666666666667, test acc:0.5276 ===
# train loss:1.03947480735
# train loss:0.912394052244
# train loss:0.980574313051
# === epoch:273, train acc:0.67, test acc:0.5325 ===
# train loss:1.16915871774
# train loss:1.15996248315
# train loss:1.15858166553
# === epoch:274, train acc:0.663333333333, test acc:0.5289 ===
# train loss:1.09761354473
# train loss:1.06157285332
# train loss:1.15955477523
# === epoch:275, train acc:0.66, test acc:0.5308 ===
# train loss:1.05909605696
# train loss:1.19112532645
# train loss:1.01980598001
# === epoch:276, train acc:0.66, test acc:0.5306 ===
# train loss:1.04212444748
# train loss:0.989940861109
# train loss:1.14302956573
# === epoch:277, train acc:0.656666666667, test acc:0.5296 ===
# train loss:1.04030845684
# train loss:1.10046881449
# train loss:1.01635712171
# === epoch:278, train acc:0.656666666667, test acc:0.5293 ===
# train loss:0.954824156541
# train loss:1.0468864491
# train loss:1.04379555287
# === epoch:279, train acc:0.66, test acc:0.5326 ===
# train loss:1.00500833325
# train loss:1.00500666227
# train loss:1.09806055141
# === epoch:280, train acc:0.663333333333, test acc:0.5317 ===
# train loss:1.0045913242
# train loss:1.14769608422
# train loss:0.962205938071
# === epoch:281, train acc:0.663333333333, test acc:0.5343 ===
# train loss:1.07462283023
# train loss:1.00400933488
# train loss:1.01168071562
# === epoch:282, train acc:0.663333333333, test acc:0.5353 ===
# train loss:1.11532803578
# train loss:0.997872122419
# train loss:0.966611023597
# === epoch:283, train acc:0.673333333333, test acc:0.5374 ===
# train loss:0.922358130527
# train loss:1.0106826218
# train loss:1.04573065799
# === epoch:284, train acc:0.673333333333, test acc:0.5402 ===
# train loss:0.926221552501
# train loss:0.941110793782
# train loss:0.985478258558
# === epoch:285, train acc:0.67, test acc:0.5372 ===
# train loss:1.07620680626
# train loss:1.06047781277
# train loss:0.835411893116
# === epoch:286, train acc:0.673333333333, test acc:0.5366 ===
# train loss:0.985120150399
# train loss:0.872087123401
# train loss:1.01503019015
# === epoch:287, train acc:0.673333333333, test acc:0.5399 ===
# train loss:0.887360213411
# train loss:0.961388831177
# train loss:1.03674958481
# === epoch:288, train acc:0.676666666667, test acc:0.5405 ===
# train loss:1.02141931562
# train loss:0.940414990985
# train loss:0.948822877171
# === epoch:289, train acc:0.676666666667, test acc:0.539 ===
# train loss:1.09918443165
# train loss:0.979174774827
# train loss:1.02395731607
# === epoch:290, train acc:0.67, test acc:0.5381 ===
# train loss:0.976869146484
# train loss:0.888078930808
# train loss:1.00399746148
# === epoch:291, train acc:0.676666666667, test acc:0.5434 ===
# train loss:1.03304746484
# train loss:0.938194986447
# train loss:0.871671629135
# === epoch:292, train acc:0.68, test acc:0.5415 ===
# train loss:0.934975349287
# train loss:0.972197285873
# train loss:0.96846973237
# === epoch:293, train acc:0.69, test acc:0.5458 ===
# train loss:0.809027075206
# train loss:0.990713008414
# train loss:0.827860677776
# === epoch:294, train acc:0.68, test acc:0.5427 ===
# train loss:0.861706526508
# train loss:0.954048620313
# train loss:0.955813393616
# === epoch:295, train acc:0.676666666667, test acc:0.5466 ===
# train loss:0.896257536822
# train loss:0.901233271511
# train loss:1.00355994969
# === epoch:296, train acc:0.686666666667, test acc:0.5492 ===
# train loss:0.931688272565
# train loss:0.945093545661
# train loss:0.982104661109
# === epoch:297, train acc:0.693333333333, test acc:0.5497 ===
# train loss:0.953711609201
# train loss:0.960745567153
# train loss:0.949684188961
# === epoch:298, train acc:0.686666666667, test acc:0.5473 ===
# train loss:1.0920364305
# train loss:0.981916801761
# train loss:1.03204917927
# === epoch:299, train acc:0.69, test acc:0.5495 ===
# train loss:0.929079334541
# train loss:1.04785470914
# train loss:1.00016824744
# === epoch:300, train acc:0.683333333333, test acc:0.5469 ===
# train loss:1.02718339747
# train loss:0.862027268355
# train loss:0.851727288385
# === epoch:301, train acc:0.686666666667, test acc:0.5462 ===
# train loss:0.830274763923
# train loss:0.962099224749
# =============== Final Test Accuracy ===============
# test acc:0.5432
